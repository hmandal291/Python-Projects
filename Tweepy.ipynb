# %%
try:
    import json
except ImportError:
    import simplejson as json

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'v0aAx9djJKI0dhi2fP0rvbJZA'
consumer_secret = '6FbkRtr7kPBh26OKHkG0nV6xjIs6fDN37YDvrj7RVJRn0EE9jH'
access_token = '245318778-5YItjvp84KPkFivFt3GC8KGm9fzGC4gETq0bGZRo'
access_secret = 'RwjbKdLmGzvXw2V6tR6tG19jAK6irxAnOskH937peJVnd'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    print(status.text)
# Out:
# Blatant Lie. https://t.co/7oJRyVTiYg
# sometimes lilliputs are better than giants.
# Celebrating #sanju 🎉 thank you everyone for the love 💖 @ Mumbai, Maharashtra https://t.co/MVeUjznb2q
# Chocolate Cake. https://t.co/rY45nZOybp
# RT @phonearena: 32GB Moto G6 just $5 a month for a limited time at Verizon; new line required - https://t.co/j5IysGiJmf https://t.co/USrKZ5…
# 😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😃 https://t.co/vMWL8a78fP
# RT @_AacharyaJi: वो ठरक मिटाने के लिए लड़कियों से व्हाटसएप्प पर न्यूडस मांगने ज़रूरीहै क्या? https://t.co/g4MISX5dtZ
# RT @EconomicTimes: #FDI growth hits 5-year low in 2017-18
# https://t.co/mec5i1ci1M
# RT @ndtv: India’s worrying spurt in mob killings
#
# @free_thinker, co-founder, Alt News, on @LRC_NDTV https://t.co/n3laXrrh1d
# Here’s some more chastening sir https://t.co/mW49f4UueJ

# %%
# define the function process_or_store
def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
for friend in tweepy.Cursor(api.favorites).items():
    process_or_store(friend._json)
# Out:
# {"created_at": "Sat Jun 30 19:13:30 +0000 2018", "id": 1013138476345315328, "id_str": "1013138476345315328", "text": "Mere trolls tumhaarey trolls sey better hain @kunalkamra88 \ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83d\ude4c\ud83c\udffe\ud83d\ude4c\ud83c\udffe\ud83d\ude4c\ud83c\udffe\ud83d\ude4c\ud83c\udffe #FreshThoughts kicked ass \u2764\ufe0f\ud83d\udc95 https://t.co/VApxi0wHY6", "truncated": false, "entities": {"hashtags": [{"text": "FreshThoughts", "indices": [71, 85]}], "symbols": [], "user_mentions": [{"screen_name": "kunalkamra88", "name": "Kunal Kamra", "id": 2259895735, "id_str": "2259895735", "indices": [45, 58]}], "urls": [], "media": [{"id": 1013138463347085312, "id_str": "1013138463347085312", "indices": [101, 124], "media_url": "http://pbs.twimg.com/media/Dg9kEIgWkAAR4GV.jpg", "media_url_https": "https://pbs.twimg.com/media/Dg9kEIgWkAAR4GV.jpg", "url": "https://t.co/VApxi0wHY6", "display_url": "pic.twitter.com/VApxi0wHY6", "expanded_url": "https://twitter.com/ReallySw
# ...

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#Neymar'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2a6896eec472> in <module>()
#      18
#      19 twitter_stream = Stream(auth, MyListener())
# ---> 20 twitter_stream.filter(track=['#Neymar'])
#
# C:\Users\decip\AppData\Local\conda\conda\envs\py36\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# C:\Users\decip\AppData\Local\conda\conda\envs\py36\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
# ...

# %%
import json
 
with open('mytweets.json', 'r') as f:
    line = f.readline() # read only the first tweet/line
    tweet = json.loads(line) # load it as Python dict
    print(json.dumps(tweet, indent=4)) # pretty-print
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-9777b2d56513> in <module>()
#       1 import json
#       2
# ----> 3 with open('python.json', 'r') as f:
#       4     line = f.readline() # read only the first tweet/line
#       5     tweet = json.loads(line) # load it as Python dict
#
# FileNotFoundError: [Errno 2] No such file or directory: 'python.json'
